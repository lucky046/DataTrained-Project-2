# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df_happiness=pd.read_csv('happiness_score_dataset.csv')
df_happiness
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df_happiness.describe
# Out:
# <bound method NDFrame.describe of          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# ...

# %%
df_happiness.Country
# Out:
# 0      Switzerland
# 1          Iceland
# 2          Denmark
# 3           Norway
# 4           Canada
#           ...
# 153         Rwanda
# 154          Benin
# 155          Syria
# 156        Burundi
# 157           Togo
# Name: Country, Length: 158, dtype: object

# %%
df_happiness.shape
# Out:
# (158, 12)

# %%
sns.heatmap(df_happiness.isnull())

# %%
df_happiness.Region
# Out:
# 0                       Western Europe
# 1                       Western Europe
# 2                       Western Europe
# 3                       Western Europe
# 4                        North America
#                     ...
# 153                 Sub-Saharan Africa
# 154                 Sub-Saharan Africa
# 155    Middle East and Northern Africa
# 156                 Sub-Saharan Africa
# 157                 Sub-Saharan Africa
# Name: Region, Length: 158, dtype: object

# %%
df_happiness.skew()
# Out:
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.barplot(y='Region', x='Dystopia Residual', data=df_happiness)
plt.show()

# %%
Happiness=df_happiness['Happiness Score']

# %%
Happiness.mean()
# Out:
# 5.3757341772151905

# %%
df_happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
from scipy.stats import zscore
z_score=abs(zscore(df_happiness))
print(df_happiness.shape)
df_happiness_final=df_virus.loc[(z.score<3).all(axis=1)]
print(df_happiness_final.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-da141d6918a1> in <module>
#       1 from scipy.stats import zscore
# ----> 2 z_score=abs(zscore(df_happiness))
#       3 print(df_happiness.shape)
#       4 df_happiness_final=df_virus.loc[(z.score<3).all(axis=1)]
#       5 print(df_happiness_final.shape)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in zscore(a, axis, ddof, nan_policy)
#    2495         sstd = np.nanstd(a=a, axis=axis, ddof=ddof, keepdims=True)
#    2496     else:
# -> 2497         mns = a.mean(axis=axis, keepdims=True)
#    2498         sstd = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2499
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
# ...

# %%
sns.lineplot(x=df_happiness['Country'], y=df_happiness['Dystopia Residual'], data=df_happiness)
plt.show()

# %%
sns.lineplot(x=df_happiness['Country'], y=df_happiness['Economy (GDP per Capita)'], data=df_happiness)
plt.show()

# %%
sns.lineplot(x=df_happiness['Region'], y=df_happiness['Economy (GDP per Capita)'], data=df_happiness)
plt.show()

# %%
sns.lineplot(x=df_happiness['Region'], y=df_happiness['Standard Error'], data=df_happiness)
plt.show()
